# %%
import requests

# Replace 'your_gemini_api_key' with your actual Gemini API key
GEMINI_API_KEY = 'AIzaSyBpYclyBRTrf8uspGypGgMznQLDWLY_d84'
GEMINI_API_URL = f'https://generativelanguage.googleapis.com/v1/models/gemini-1.5-flash:generateContent?key={GEMINI_API_KEY}'  # Hypothetical endpoint

def generate_qa_pairs(paragraph):
    headers = {
        "Content-Type": "application/json",
    }
    data = {
        "contents": [
            {
                "parts": [
                    {"text": f"Generate QA pairs from the following paragraph: {paragraph}"}
                ]
            }
        ]
    }

    try:
        response = requests.post(GEMINI_API_URL, headers=headers, json=data)
        response.raise_for_status()  # Raise an error for bad responses

        # Print the entire response for debugging
        print("Response JSON:", response.json())

        # Extract the generated text from the response
        generated_text = response.json().get('generated_text', '')

        # Print the generated text for debugging
        print("Generated Text:", generated_text)

        # Parse the generated text into QA pairs
        qa_pairs = []
        questions_and_answers = generated_text.split("Q:")
        for qa in questions_and_answers:
            if "A:" in qa:
                question, answer = qa.split("A:")
                qa_pairs.append((question.strip(), answer.strip()))

        return qa_pairs

    except Exception as e:
        print(f"An error occurred: {e}")
        return []

# Example usage
paragraph = "Artificial intelligence (AI) is intelligence demonstrated by machines, in contrast to the natural intelligence displayed by humans and animals. Leading AI textbooks define the field as the study of 'intelligent agents': any device that perceives its environment and takes actions that maximize its chance of successfully achieving its goals."

qa_pairs = generate_qa_pairs(paragraph)

for i, (question, answer) in enumerate(qa_pairs):
    print(f"Q{i+1}: {question}")
    print(f"A{i+1}: {answer}\n")
# Out:
# Response JSON: {'candidates': [{'content': {'parts': [{'text': "## QA Pairs from the Paragraph:\n\n**Q1: What is artificial intelligence?**\n**A1:** Artificial intelligence (AI) is intelligence demonstrated by machines, in contrast to the natural intelligence shown by humans and animals.\n\n**Q2: How does AI differ from natural intelligence?**\n**A2:**  AI is intelligence demonstrated by machines, while natural intelligence is displayed by humans and animals.\n\n**Q3: What is the focus of study in the field of AI according to leading textbooks?**\n**A3:** Leading AI textbooks define the field as the study of 'intelligent agents'.\n\n**Q4: What is an 'intelligent agent' in the context of AI?**\n**A4:** An 'intelligent agent' is any device that perceives its environment and takes actions to maximize its chance of achieving its goals.\n\n**Q5: What is the primary goal of an intelligent agent?**\n**A5:** An intelligent agent aims to maximize its chance of successfully achieving its goals
# ...

# %%
import requests

# Replace 'your_gemini_api_key' with your actual Gemini API key
GEMINI_API_KEY = 'AIzaSyBpYclyBRTrf8uspGypGgMznQLDWLY_d84'
GEMINI_API_URL = f'https://generativelanguage.googleapis.com/v1/models/gemini-1.5-flash:generateContent?key={GEMINI_API_KEY}'  # Hypothetical endpoint

def generate_qa_pairs(paragraph):
    headers = {
        "Content-Type": "application/json",
    }
    data = {
        "contents": [
            {
                "parts": [
                    {"text": f"Generate QA pairs from the following paragraph: {paragraph}"}
                ]
            }
        ]
    }

    try:
        response = requests.post(GEMINI_API_URL, headers=headers, json=data)
        response.raise_for_status()  # Raise an error for bad responses

        # Print the entire response for debugging
        print("Response JSON:", response.json())

        # Extract the generated text from the response
        generated_text = response.json().get('generated_text', '')

        # Print the generated text for debugging
        print("Generated Text:", generated_text)

        # Parse the generated text into QA pairs
        qa_pairs = []
        questions_and_answers = generated_text.split("Q:")
        for qa in questions_and_answers:
            if "A:" in qa:
                question, answer = qa.split("A:")
                qa_pairs.append((question.strip(), answer.strip()))

        return qa_pairs

    except Exception as e:
        print(f"An error occurred: {e}")
        return []

# Example usage
paragraph = "Artificial intelligence (AI) is intelligence demonstrated by machines, in contrast to the natural intelligence displayed by humans and animals. Leading AI textbooks define the field as the study of 'intelligent agents': any device that perceives its environment and takes actions that maximize its chance of successfully achieving its goals."

qa_pairs = generate_qa_pairs(paragraph)

for i, (question, answer) in enumerate(qa_pairs):
    print(f"Q{i+1}: {question}")
    print(f"A{i+1}: {answer}\n")
# Out:
# Response JSON: {'candidates': [{'content': {'parts': [{'text': "## QA Pairs:\n\n**Q1: What is artificial intelligence (AI)?**\n\n**A1:** Artificial intelligence (AI) is intelligence displayed by machines, unlike the natural intelligence seen in humans and animals.\n\n**Q2: How is AI defined in leading textbooks?**\n\n**A2:** Leading AI textbooks define the field as the study of 'intelligent agents', which are devices that can perceive their environment and act to maximize their chances of achieving their goals.\n\n**Q3: What distinguishes AI from natural intelligence?**\n\n**A3:** AI is displayed by machines, while natural intelligence is seen in humans and animals.\n\n**Q4: What is an 'intelligent agent' in the context of AI?**\n\n**A4:** An 'intelligent agent' is any device that can perceive its environment and take actions to maximize its chances of achieving its goals. \n"}], 'role': 'model'}, 'finishReason': 'STOP', 'index': 0, 'safetyRatings': [{'category': 'HARM_CATEGORY_SEXUA
# ...

# %%
import requests

# Replace 'your_gemini_api_key' with your actual Gemini API key
GEMINI_API_KEY = 'AIzaSyBpYclyBRTrf8uspGypGgMznQLDWLY_d84'
GEMINI_API_URL = f'https://generativelanguage.googleapis.com/v1/models/gemini-1.5-flash:generateContent?key={GEMINI_API_KEY}'  # Hypothetical endpoint

def generate_qa_pairs(paragraph):
    headers = {
        "Content-Type": "application/json",
    }
    data = {
        "contents": [
            {
                "parts": [
                    {"text": f"Generate QA pairs from the following paragraph: {paragraph}"}
                ]
            }
        ]
    }

    try:
        response = requests.post(GEMINI_API_URL, headers=headers, json=data)
        response.raise_for_status()  # Raise an error for bad responses

        # Extract the generated text from the response
        candidates = response.json().get('candidates', [])
        if not candidates:
            return []

        generated_text = candidates[0].get('content', {}).get('parts', [{}])[0].get('text', '')

        # Print the generated text for debugging
        print("Generated Text:", generated_text)

        # Parse the generated text into QA pairs
        qa_pairs = []
        questions_and_answers = generated_text.split("Q:")
        for qa in questions_and_answers:
            if "A:" in qa:
                question, answer = qa.split("A:")
                qa_pairs.append((question.strip(), answer.strip()))

        return qa_pairs

    except Exception as e:
        print(f"An error occurred: {e}")
        return []

# Example usage
paragraph = "Artificial intelligence (AI) is intelligence demonstrated by machines, in contrast to the natural intelligence displayed by humans and animals. Leading AI textbooks define the field as the study of 'intelligent agents': any device that perceives its environment and takes actions that maximize its chance of successfully achieving its goals."

qa_pairs = generate_qa_pairs(paragraph)

for i, (question, answer) in enumerate(qa_pairs):
    print(f"Q{i+1}: {question}")
    print(f"A{i+1}: {answer}\n")
# Out:
# Generated Text: ## QA Pairs:
#
# **Q1: What is artificial intelligence (AI)?**
# **A1:** Artificial intelligence (AI) is intelligence demonstrated by machines, as opposed to the natural intelligence of humans and animals.
#
# **Q2: How is AI different from natural intelligence?**
# **A2:** AI is intelligence displayed by machines, while natural intelligence is exhibited by humans and animals.
#
# **Q3: According to AI textbooks, what is the focus of the field?**
# **A3:** Leading AI textbooks define the field as the study of 'intelligent agents'.
#
# **Q4: What are 'intelligent agents'?**
# **A4:**  'Intelligent agents' are devices that perceive their environment and take actions to maximize their chance of achieving their goals.
#
# **Q5: What is the goal of an intelligent agent?**
# **A5:**  An intelligent agent aims to maximize its chance of achieving its goals.

# %%
import requests

# Replace 'your_gemini_api_key' with your actual Gemini API key
GEMINI_API_KEY = 'AIzaSyBpYclyBRTrf8uspGypGgMznQLDWLY_d84'
GEMINI_API_URL = f'https://generativelanguage.googleapis.com/v1/models/gemini-1.5-flash:generateContent?key={GEMINI_API_KEY}'  # Hypothetical endpoint

def generate_qa_pairs(paragraph, num_pairs):
    headers = {
        "Content-Type": "application/json",
    }
    data = {
        "contents": [
            {
                "parts": [
                    {"text": f"Generate QA pairs from the following paragraph: {paragraph}"}
                ]
            }
        ]
    }

    try:
        response = requests.post(GEMINI_API_URL, headers=headers, json=data)
        response.raise_for_status()  # Raise an error for bad responses

        # Extract the generated text from the response
        candidates = response.json().get('candidates', [])
        if not candidates:
            return []

        generated_text = candidates[0].get('content', {}).get('parts', [{}])[0].get('text', '')

        # Print the generated text for debugging
        print("Generated Text:", generated_text)

        # Parse the generated text into QA pairs
        qa_pairs = []
        questions_and_answers = generated_text.split("Q:")
        for qa in questions_and_answers:
            if "A:" in qa:
                question, answer = qa.split("A:")
                qa_pairs.append((question.strip(), answer.strip()))

        return qa_pairs[:num_pairs]  # Return only the specified number of pairs

    except Exception as e:
        print(f"An error occurred: {e}")
        return []

# Example usage
paragraph = "Artificial intelligence (AI) is intelligence demonstrated by machines, in contrast to the natural intelligence displayed by humans and animals. Leading AI textbooks define the field as the study of 'intelligent agents': any device that perceives its environment and takes actions that maximize its chance of successfully achieving its goals."
num_pairs = 3  # Specify the number of pairs you want to print

qa_pairs = generate_qa_pairs(paragraph, num_pairs)

for i, (question, answer) in enumerate(qa_pairs):
    print(f"Q{i+1}: {question}")
    print(f"A{i+1}: {answer}\n")
# Out:
# Generated Text: ## QA Pairs from the Paragraph:
#
# **Q1: What is artificial intelligence (AI)?**
#
# **A1:** Artificial intelligence (AI) is intelligence demonstrated by machines, as opposed to the natural intelligence of humans and animals.
#
# **Q2: How is AI distinguished from natural intelligence?**
#
# **A2:** AI is distinguished from natural intelligence by being displayed by machines, while natural intelligence is exhibited by humans and animals.
#
# **Q3: What is the focus of study in the field of AI, according to leading textbooks?**
#
# **A3:** Leading AI textbooks define the field as the study of "intelligent agents," which are devices that perceive their environment and act to maximize their chances of achieving goals.
#
# **Q4: What are the key characteristics of an "intelligent agent" in AI?**
#
# **A4:** Intelligent agents in AI are devices that perceive their environment and take actions to optimize their chances of successfully achieving their goals.
#
# ...

# %%
def generate_qa_pairs(paragraph, num_pairs):
    headers = {
        "Content-Type": "application/json",
    }
    data = {
        "contents": [
            {
                "parts": [
                    {"text": f"Generate QA pairs from the following paragraph: {paragraph}"}
                ]
            }
        ]
    }

    try:
        response = requests.post(GEMINI_API_URL, headers=headers, json=data)
        response.raise_for_status()  # Raise an error for bad responses

        # Extract the generated text from the response
        candidates = response.json().get('candidates', [])
        if not candidates:
            return []

        generated_text = candidates[0].get('content', {}).get('parts', [{}])[0].get('text', '')

        # Print the generated text for debugging
        print("Generated Text:", generated_text)

        # Parse the generated text into QA pairs
        qa_pairs = []
        lines = generated_text.split("\n")
        question = None
        for line in lines:
            if line.startswith("**Q"):
                if question:  # If there's a previous question, add the QA pair
                    qa_pairs.append((question.strip(), answer.strip()))
                question = line.lstrip("**Q").strip()  # Remove "**Q" from the beginning of the line
                answer = None  # Reset answer for the new question
            elif line.startswith("**A"):
                answer = line.lstrip("**A").strip()  # Remove "**A" from the beginning of the line

        # Add the last QA pair if it exists
        if question and answer:
            qa_pairs.append((question.strip(), answer.strip()))

        return qa_pairs[:num_pairs]  # Return only the specified number of pairs

    except Exception as e:
        print(f"An error occurred: {e}")
        return []

# %%
def generate_qa_pairs(paragraph, num_pairs):
    headers = {
        "Content-Type": "application/json",
    }
    data = {
        "contents": [
            {
                "parts": [
                    {"text": f"Generate QA pairs from the following paragraph: {paragraph}"}
                ]
            }
        ]
    }

    try:
        response = requests.post(GEMINI_API_URL, headers=headers, json=data)
        response.raise_for_status()  # Raise an error for bad responses

        # Extract the generated text from the response
        candidates = response.json().get('candidates', [])
        if not candidates:
            return []

        generated_text = candidates[0].get('content', {}).get('parts', [{}])[0].get('text', '')

        # Print the generated text for debugging
        print("Generated Text:", generated_text)

        # Parse the generated text into QA pairs
        qa_pairs = []
        lines = generated_text.split("\n")
        question = None
        for line in lines:
            if line.startswith("**Q"):
                if question:  # If there's a previous question, add the QA pair
                    qa_pairs.append((f"{question.strip()}", f"{answer.strip()}"))
                question = line.lstrip("**Q").replace("**", "").strip()  # Remove "**" and numbering from the beginning of the line
                answer = None  # Reset answer for the new question
            elif line.startswith("**A"):
                answer = line.lstrip("**A").replace("**", "").strip()  # Remove "**" from the beginning of the line

        # Add the last QA pair if it exists
        if question and answer:
            qa_pairs.append((f"{question.strip()}", f"{answer.strip()}"))

        return qa_pairs[:num_pairs]  # Return only the specified number of pairs

    except Exception as e:
        print(f"An error occurred: {e}")
        return []

# %%
# Example usage
paragraph = "Artificial intelligence (AI) is intelligence demonstrated by machines, in contrast to the natural intelligence displayed by humans and animals. Leading AI textbooks define the field as the study of 'intelligent agents': any device that perceives its environment and takes actions that maximize its chance of successfully achieving its goals."
num_pairs = 1  # Specify the number of pairs you want to print

qa_pairs = generate_qa_pairs(paragraph, num_pairs)

# Check if generated text is not empty
if qa_pairs:
    # Store the generated QA pairs in one variable
    all_qa_pairs = qa_pairs
    print(all_qa_pairs)
else:
    print("No QA pairs generated.")
# Out:
# [('1: What is artificial intelligence (AI)?', '1: Artificial intelligence (AI) is intelligence demonstrated by machines, as opposed to the natural intelligence exhibited by humans and animals.')]

# %%
from nltk.translate.bleu_score import corpus_bleu

# Example reference questions and answers
reference_questions_answers = [
    ('What is artificial intelligence (AI)?', 'Artificial intelligence (AI) is intelligence demonstrated by machines, in contrast to the natural intelligence displayed by humans and animals.')
    # Add more reference question-answer pairs if you have them
]

# Example generated questions and answers
generated_questions_answers = [
    (q.replace('1:', '').strip(), a.replace('1:', '').strip()) for q, a in all_qa_pairs
    # Replace all_qa_pairs with your actual list of generated questions and answers
]

# Calculate BLEU score
bleu_score = corpus_bleu([[ref_ans.split()] for _, ref_ans in reference_questions_answers], [gen_ans.split() for gen_q, gen_ans in generated_questions_answers])

print("BLEU Score:", bleu_score)
# Out:
# BLEU Score: 0.6289868866690355
